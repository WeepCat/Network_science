# %% [markdown]
# 我们将使用 PyTorch Geometric (PyG) 框架学习 GCN，应用于图分类任务。 图分类是指在给定图数据集的情况下，根据某些结构图属性对整个图进行分类的问题。
#
# 图分类最常见的任务是分子属性预测，其中分子被表示为图，任务可能是推断分子是否抑制HIV病毒复制。
#
# 多特蒙德工业大学收集了各种不同的图形分类数据集，称为 TUDatasets，可以通过 PyTorch Geometric 中的 torch_geometric.datasets.TUDataset 访问。 让我们加载并检查较小的数据集之一，即 MUTAG 数据集：

# %%
import torch
from torch_geometric.datasets import TUDataset

# %%
dataset = TUDataset(root='data/TUDataset', name='MUTAG') # 加载数据集

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # 得到数据中的第一个图

print()
print(data)
print('=============================================================')

# 获得图的一些统计特征
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Dataset: MUTAG(188):
# ====================
# Number of graphs: 188
# Number of features: 7
# Number of classes: 2
#
# Data(edge_index=[2, 38], x=[17, 7], edge_attr=[38, 4], y=[1])
# =============================================================
# Number of nodes: 17
# Number of edges: 38
# Average node degree: 2.24
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %% [markdown]
# 该数据集提供了 188 个不同的图，任务是将每个图分类为两类中的一类。通过检查数据集的第一个图对象，我们可以看到它有 17 个节点（具有 7 维特征向量）和 38条边（平均节点度为2.24`），它还有一个标签 (y=[1])。除了之前的数据集之外，还提供了额外的 4 维边缘特征 (edge_attr=[38, 4])。 然而，为了简单起见，我们这次不会使用它们。
#
# PyTorch Geometric 提供了一些有用的实用程序来处理图数据集，例如，我们可以打乱数据集并使用前 150 个图作为训练图，同时使用剩余的图形进行测试：

# %%
torch.manual_seed(12345)
dataset = dataset.shuffle()

train_dataset = dataset[:150]
test_dataset = dataset[150:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 150
# Number of test graphs: 38

# %% [markdown]
# 批处理对于图数据比较复杂和麻烦。PyTorch Geometric 选择了一种和常见图像数据集不同的方法来实现多个示例的并行化。 在这里，邻接矩阵以对角方式堆叠（创建一个包含多个孤立子图的巨型图），并且节点和目标特征在节点维度中简单地连接。与其他批处理程序相比，该程序具有一些关键优势：（1）依赖于消息传递方案的 GNN 算子不需要修改，因为属于不同图的两个节点之间不会交换消息；（2）由于邻接矩阵以稀疏方式保存，仅保存非零条目（即边），因此不存在计算或内存开销。
#
# PyTorch Geometric 在 torch_geometric.data.DataLoader 类的帮助下自动将多个图批处理为单个巨型图，我们并不需要手动进行上述的复杂步骤。

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# **训练 GNN 进行图分类通常遵循一个简单的方法：**
#
# -   通过执行多轮消息传递来嵌入每个节点。
# -   将节点嵌入聚合为统一的图嵌入（读出层）。
# -   在图嵌入上训练最终分类器。
#
# 对于整图分类，我们需要一个读出层（readout layer），但最常见的一种是简单地取节点嵌入的平均值：
# $$
# x_{out} = \frac{1}{\vert V \vert} \sum_{v \in V}x_{v}^{(L)}
# $$
# PyTorch Geometric 通过 torch_geometric.nn.global_mean_pool 提供此功能，它接受小批量中所有节点的节点嵌入和分配向量批量，以计算批量中每个图的大小为 [batch_size, hide_channels] 的图嵌入。也就是说，我们在这里不需要考虑批大小。
#
# 将 GNN 应用到图分类任务的最终架构如下所示，并允许完整的端到端训练：

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, in_features, hidden_features):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        # 使用 GCNConv 
        # 为了让模型更稳定我们也可以使用带有跳跃链接的 GraphConv
        # from torch_geometric.nn import GraphConv
        self.conv1 = GCNConv(in_features, hidden_features)
        self.conv2 = GCNConv(hidden_features, hidden_features)
        self.lin = Linear(hidden_features, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        # 1. 获得节点的嵌入
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()

        # 2. 读出层
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. 应用最后的分类器
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(in_features=dataset.num_features, hidden_features=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(7, 64)
#   (conv2): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# 在这里，我们再次使用 GCNConv 和 ReLU(x)=max(x,0) 激活来获得局部节点嵌入，然后再将最终分类器应用到图读出层之上。
#
# 让我们训练我们的网络几个周期，看看它在训练和测试集上的表现如何：

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # 迭代获得各个批数据
         out = model(data.x, data.edge_index, data.batch)  # 前向传播
         loss = criterion(out, data.y)  # 计算损失
         loss.backward()  # 反向传播
         optimizer.step()  # 参数更新
         optimizer.zero_grad()  # 梯度清零

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # 迭代获得各个批数据
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # 取最大概率的类作为预测
         correct += int((pred == data.y).sum())  # 与真实标签做比较
     return correct / len(loader.dataset)  # 计算准确率


for epoch in range(1, 171):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 002, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 003, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 004, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 005, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 006, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 007, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 008, Train Acc: 0.6533, Test Acc: 0.7368
# Epoch: 009, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 010, Train Acc: 0.6600, Test Acc: 0.7632
# Epoch: 011, Train Acc: 0.6600, Test Acc: 0.7632
# Epoch: 012, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 013, Train Acc: 0.7267, Test Acc: 0.7632
# Epoch: 014, Train Acc: 0.7267, Test Acc: 0.7632
# Epoch: 015, Train Acc: 0.7200, Test Acc: 0.7632
# Epoch: 016, Train Acc: 0.7067, Test Acc: 0.7895
# Epoch: 017, Train Acc: 0.7067, Test Acc: 0.7895
# Epoch: 018, Train Acc: 0.7133, Test Acc: 0.7895
# Epoch: 019, Train Acc: 0.7133, Test Acc: 0.7895
# Epoch: 020, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 021, Train Acc: 0.7200, Test Acc: 0.7895
# Epoch: 022, Train Acc: 0.7133, Test Acc: 0.8158
# Epoch: 023, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 024, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 025, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 026, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 027, Train Acc: 0.7200, Test Acc: 0.7895
# Epoch: 028, Train Acc: 0.7267, Test Acc: 0.7895
# Epoch: 029, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 030, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 031, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 032, Train Acc: 0.7267, Test Acc: 0.8158
# Epoch: 033, Train Acc: 0.7267, Test Acc: 0.8158
# Epoch: 034, Train Acc: 0.7400, Test Acc: 0.7895
# Epoch: 035, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 036, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 037, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 038, Train Acc: 0.7533, Test Acc: 0.7895
# Epoch: 039, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 040, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 041, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 042, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 043, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 044, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 045, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 046, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 047, Train Acc: 0.7533, Test Acc: 0.7895
# Epoch: 048, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 049, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 050, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 051, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 052, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 053, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 054, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 055, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 056, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 057, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 058, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 059, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 060, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 061, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 062, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 063, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 064, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 065, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 066, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 067, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 068, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 069, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 070, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 071, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 072, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 073, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 074, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 075, Train Acc: 0.7600, Test Acc: 0.7895
# Epoch: 076, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 077, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 078, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 079, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 080, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 081, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 082, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 083, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 084, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 085, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 086, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 087, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 088, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 089, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 090, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 091, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 092, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 093, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 094, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 095, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 096, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 097, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 098, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 099, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 100, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 101, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 102, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 103, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 104, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 105, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 106, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 107, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 108, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 109, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 110, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 111, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 112, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 113, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 114, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 115, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 116, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 117, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 118, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 119, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 120, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 121, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 122, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 123, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 124, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 125, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 126, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 127, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 128, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 129, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 130, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 131, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 132, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 133, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 134, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 135, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 136, Train Acc: 0.7800, Test Acc: 0.7895
# Epoch: 137, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 138, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 139, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 140, Train Acc: 0.7800, Test Acc: 0.8421
# Epoch: 141, Train Acc: 0.7933, Test Acc: 0.8158
# Epoch: 142, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 143, Train Acc: 0.7667, Test Acc: 0.7368
# Epoch: 144, Train Acc: 0.7667, Test Acc: 0.7368
# Epoch: 145, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 146, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 147, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 148, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 149, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 150, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 151, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 152, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 153, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 154, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 155, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 156, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 157, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 158, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 159, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 160, Train Acc: 0.7600, Test Acc: 0.7368
# Epoch: 161, Train Acc: 0.7533, Test Acc: 0.7368
# Epoch: 162, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 163, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 164, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 165, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 166, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 167, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 168, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 169, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 170, Train Acc: 0.7733, Test Acc: 0.7632
